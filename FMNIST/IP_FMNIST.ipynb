# %% [markdown]
# # shallow Autoencoders

# %%
import Shallow_AE
Shallow_AE.main()
# Out:
# Training Starts!
# Training Ends!
# Estimating Mutual Information...

# %% [markdown]
# # Deep Autoencoders

# %%
import Deep_AE
Deep_AE.main()
# Out:
# Training Starts!
# Training Ends!
# Estimating Mutual Information...

# %% [markdown]
# # Deep Autoencoders with overfitting

# %%
import Deep_AE_overfit
Deep_AE_overfit.main()
# Out:
# Training Starts!
# Training Ends!
# Estimating Mutual Information...

# %% [markdown]
# # Sparse Autoencoders

# %%
import SAE
SAE.main()
# Out:
# Training Starts!
# Training Ends!
# Estimating Mutual Information...

# %% [markdown]
# # Tied Autoencoders

# %%
import TAE
TAE.main()
# Out:
# Training Starts!
# Training Ends!
# Estimating Mutual Information...

# %% [markdown]
# # Variational Autoencoders

# %%
import VAE
VAE.main()
# Out:
# Training Starts!
# Training Ends!
# Estimating Mutual Information...

# %% [markdown]
# # Label Autoencoders

# %%
import LAE
LAE.main()
# Out:
# Training Starts!
# Training Ends!
# Estimating Mutual Information...
